# %%
from math import pi
import matplotlib.pyplot as plt
from pennylane import numpy as np
import pennylane as qml
from pennylane.optimize import AdamOptimizer
import datetime
now=datetime.datetime.now

# %%
num_qubits=2
dev=qml.device('default.qubit', wires=num_qubits)

# %%
#Analytic Solution
def U(t):
    return np.sin(t)+1

# %%
def FE1(U_prime,t):         # U_prime = cos(t) , U(0)=1
    return U_prime - np.cos(t)

# %%
t=np.random.uniform(0,2*np.pi,size=100,requires_grad=False)

# %%
# define embedding layer
def embedding(x,wires):
    qml.RY(x, wires=wires[1])

# %%
def Ham():
    obs=[]
    for j in range(num_qubits):
        obs.append(qml.PauliX(j))
        for k in range(j):
            obs.append(qml.PauliZ(j)@qml.PauliZ(k))
    coeffs=np.random.uniform(-1,1,len(obs))*10
    qml.Hamiltonian(coeffs, obs)

# %%
# define ansastz layer
def layer(theta):
    
    # Apply Hamiltonian matrix
    Ham()
    
    # Apply H gate
    qml.Hadamard(0)
    
    # rotations on qubit 1
    qml.RY(theta,wires=1)
    
    # CNOT
    qml.CNOT(wires=[0, 1])

# %%
@qml.qnode(dev, diff_method="backprop", interface="autograd")
def quantum_net(theta,x):
    
    # encode data
    embedding(x,wires=range(num_qubits))
    
    # parameterized circuit layers
    for v in theta: # (for lool along with the first dimension)
        # print(v)
        # Ham()
        layer(v)
    
    qml.Hadamard(0)
    
    # return qml.expval(qml.PauliZ(0)),qml.expval(qml.PauliZ(1))
    return qml.expval(qml.PauliZ(0))

# %%
num_layers=4
theta=np.random.uniform(0,2*pi,size=(num_layers,num_qubits-1),requires_grad=True)
# theta = np.load('my_theta1.npy')
print(theta)
print(qml.draw(quantum_net)(theta,0))
# Out:
# [[0.44875154]
#  [1.06482504]
#  [2.81060341]
#  [2.38159632]]
# 0: ──H────────────────╭●──H──────╭●──H──────╭●──H──────╭●──H─┤  <Z>
# 1: ──RY(0.00)──RY(M0)─╰X──RY(M1)─╰X──RY(M2)─╰X──RY(M3)─╰X────┤

# %%
# add the classical layer   #TODO
def classical_quantum_net(theta,w,t):
    r1=quantum_net(theta,t)[0]
    # r2=quantum_net(theta,x)[1]
    # return w[0]+w[1]*r1+w[2]*r1**2+w[3]*r2+w[4]*r2**2
    return w[0]+w[1]*r1+w[2]*r1**2
    # r1=quantum_net(theta,t)[0]
    # return r1

# %%
def classical_quantum_net_prime(theta,w,t):
    r1=quantum_net(theta,t)[0]
    r1_prime = qml.grad(quantum_net,argnum=1)(theta,np.tensor(t)) 
    # r2=quantum_net(theta,x)[1]
    # return w[0]+w[1]*r1+w[2]*r1**2+w[3]*r2+w[4]*r2**2
    return w[1]*r1_prime+2*w[2]*r1_prime*r1

# %%
# def square_loss(labels,predictions):
#     loss=0
#     for l,p in zip(labels,predictions):
#         loss=loss+(l-p)**2
#     loss=loss/len(labels)
#     return loss

# %%
# #loss boundary
# def loss_b(U_predict):

# %%
def cost(theta,w,t):
# def cost(theta,t):
    # loss inner points
    loss_i = 0
    # U_prime = np.array([qml.grad(quantum_net,argnum=1)(theta,np.tensor(point)) for point in t])
    U_prime = np.array([classical_quantum_net_prime(theta,w,point) for point in t])
    # preds=[classical_quantum_net(theta,w,t) for t in t]
    loss_i += np.mean(FE1(U_prime=U_prime,t=t)**2)
    
    # loss boundary points
    loss_b = 0
    U_0 = classical_quantum_net(theta,w,0)
    # print(U_0)
    loss_b += (U_0-1)**2
    return 0.2*loss_b + 0.8*loss_i

# %%
w=np.zeros(5,requires_grad=True)
opt = AdamOptimizer(0.05, beta1=0.9, beta2=0.999)

# %%
start=now()
print(start)
# Out:
# 2023-07-31 16:49:53.063449

# %%
epochs=130
for e in range(1,epochs+1):
    (theta,w,_),_cost=opt.step_and_cost(cost,theta,w,t)
    # (theta,_),_cost=opt.step_and_cost(cost,theta,t)
    if e==1 or e%10==0:
        print(f'Epoch: {e} | Cost: {_cost}')
# Out:
# Epoch: 1 | Cost: 0.5757659703164897
# Epoch: 10 | Cost: 0.37225479061205563
# Epoch: 20 | Cost: 0.23094633066490144
# Epoch: 30 | Cost: 0.05719729632054967
# Epoch: 40 | Cost: 0.02531306876306735
# Epoch: 50 | Cost: 0.019835096816853824
# Epoch: 60 | Cost: 0.008428133926604435
# Epoch: 70 | Cost: 0.003184624198900419
# Epoch: 80 | Cost: 0.00114492600739512
# Epoch: 90 | Cost: 0.00031830346801006026
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 epochs=130
#       2 for e in range(1,epochs+1):
# ----> 3     (theta,w,_),_cost=opt.step_and_cost(cost,theta,w,t)
#       4     # (theta,_),_cost=opt.step_and_cost(cost,theta,t)
#       5     if e==1 or e%10==0:
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/optimize/gradient_descent.py:59, in GradientDescentOptimizer.step_and_cost(self, objective_fn, grad_fn, *args, **kwargs)
#      39 def step_and_cost(self, objective_fn, *args, grad_fn=None, **kwargs):
#      40     """Update trainable arguments with one step of the optimizer and return the corresponding
#      41     objective function value prior to the step.
#      42
#    (...)
#      56         If single arg is provided, list [array] is replaced by array.
#      57     """
# ---> 59     g, forward = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      60     new_args = self.apply_grad(g, args)
#      62     if forward is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/optimize/gradient_descent.py:117, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#      99 r"""Compute gradient of the objective function at the given point and return it along with
#     100 the objective function forward pass (if available).
#     101
#    (...)
#     114     will not be evaluted and instead ``None`` will be returned.
#     115 """
#     116 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 117 grad = g(*args, **kwargs)
#     118 forward = getattr(g, "forward", None)
#     120 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_grad.py:117, in grad.__call__(self, *args, **kwargs)
#     114     self._forward = self._fun(*args, **kwargs)
#     115     return ()
# --> 117 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     118 self._forward = ans
#     120 return grad_value
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_grad.py:135, in grad._grad_with_forward(fun, x)
#     129 @staticmethod
#     130 @unary_to_nary
#     131 def _grad_with_forward(fun, x):
#     132     """This function is a replica of ``autograd.grad``, with the only
#     133     difference being that it returns both the gradient *and* the forward pass
#     134     value."""
# --> 135     vjp, ans = _make_vjp(fun, x)
#     137     if not vspace(ans).size == 1:
#     138         raise TypeError(
#     139             "Grad only applies to real scalar-output functions. "
#     140             "Try jacobian, elementwise_grad or holomorphic_grad."
#     141         )
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# Cell In[15], line 6, in cost(theta, w, t)
#       4 loss_i = 0
#       5 # U_prime = np.array([qml.grad(quantum_net,argnum=1)(theta,np.tensor(point)) for point in t])
# ----> 6 U_prime = np.array([classical_quantum_net_prime(theta,w,point) for point in t])
#       7 # preds=[classical_quantum_net(theta,w,t) for t in t]
#       8 loss_i += np.mean(FE1(U_prime=U_prime,t=t)**2)
#
# Cell In[15], line 6, in <listcomp>(.0)
#       4 loss_i = 0
#       5 # U_prime = np.array([qml.grad(quantum_net,argnum=1)(theta,np.tensor(point)) for point in t])
# ----> 6 U_prime = np.array([classical_quantum_net_prime(theta,w,point) for point in t])
#       7 # preds=[classical_quantum_net(theta,w,t) for t in t]
#       8 loss_i += np.mean(FE1(U_prime=U_prime,t=t)**2)
#
# Cell In[12], line 3, in classical_quantum_net_prime(theta, w, t)
#       1 def classical_quantum_net_prime(theta,w,t):
#       2     r1=quantum_net(theta,t)[0]
# ----> 3     r1_prime = qml.grad(quantum_net,argnum=1)(theta,np.tensor(t))
#       4     # r2=quantum_net(theta,x)[1]
#       5     # return w[0]+w[1]*r1+w[2]*r1**2+w[3]*r2+w[4]*r2**2
#       6     return w[1]*r1_prime+2*w[2]*r1_prime*r1
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_grad.py:117, in grad.__call__(self, *args, **kwargs)
#     114     self._forward = self._fun(*args, **kwargs)
#     115     return ()
# --> 117 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     118 self._forward = ans
#     120 return grad_value
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_grad.py:135, in grad._grad_with_forward(fun, x)
#     129 @staticmethod
#     130 @unary_to_nary
#     131 def _grad_with_forward(fun, x):
#     132     """This function is a replica of ``autograd.grad``, with the only
#     133     difference being that it returns both the gradient *and* the forward pass
#     134     value."""
# --> 135     vjp, ans = _make_vjp(fun, x)
#     137     if not vspace(ans).size == 1:
#     138         raise TypeError(
#     139             "Grad only applies to real scalar-output functions. "
#     140             "Try jacobian, elementwise_grad or holomorphic_grad."
#     141         )
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/qnode.py:867, in QNode.__call__(self, *args, **kwargs)
#     865     self.execute_kwargs.pop("mode")
#     866 # pylint: disable=unexpected-keyword-arg
# --> 867 res = qml.execute(
#     868     [self.tape],
#     869     device=self.device,
#     870     gradient_fn=self.gradient_fn,
#     871     interface=self.interface,
#     872     gradient_kwargs=self.gradient_kwargs,
#     873     override_shots=override_shots,
#     874     **self.execute_kwargs,
#     875 )
#     877 res = res[0]
#     879 if old_interface == "auto":
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/interfaces/execution.py:407, in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     403     return batch_fn(res)
#     405 if gradient_fn == "backprop" or interface is None:
#     406     return batch_fn(
# --> 407         qml.interfaces.cache_execute(
#     408             batch_execute, cache, return_tuple=False, expand_fn=expand_fn
#     409         )(tapes)
#     410     )
#     412 # the default execution function is batch_execute
#     413 execute_fn = qml.interfaces.cache_execute(batch_execute, cache, expand_fn=expand_fn)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/interfaces/execution.py:204, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     200         return (res, []) if return_tuple else res
#     202 else:
#     203     # execute all unique tapes that do not exist in the cache
# --> 204     res = fn(execution_tapes.values(), **kwargs)
#     206 final_res = []
#     208 for i, tape in enumerate(tapes):
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/interfaces/execution.py:130, in cache_execute.<locals>.fn(tapes, **kwargs)
#     128 def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     129     tapes = [expand_fn(tape) for tape in tapes]
# --> 130     return original_fn(tapes, **kwargs)
#
# File ~/anaconda3/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_qubit_device.py:588, in QubitDevice.batch_execute(self, circuits)
#     583 for circuit in circuits:
#     584     # we need to reset the device here, else it will
#     585     # not start the next computation in the zero state
#     586     self.reset()
# --> 588     res = self.execute(circuit)
#     589     results.append(res)
#     591 if self.tracker.active:
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/_qubit_device.py:318, in QubitDevice.execute(self, circuit, **kwargs)
#     315 self.check_validity(circuit.operations, circuit.observables)
#     317 # apply all circuit operations
# --> 318 self.apply(circuit.operations, rotations=self._get_diagonalizing_gates(circuit), **kwargs)
#     320 # generate computational basis samples
#     321 if self.shots is not None or circuit.is_sampled:
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:276, in DefaultQubit.apply(self, operations, rotations, **kwargs)
#     274         self._state = self._apply_parametrized_evolution(self._state, operation)
#     275     else:
# --> 276         self._state = self._apply_operation(self._state, operation)
#     278 # store the pre-rotated state
#     279 self._pre_rotated_state = self._state
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:316, in DefaultQubit._apply_operation(self, state, operation)
#     313     axes = [ax + shift for ax in self.wires.indices(wires)]
#     314     return self._apply_ops[operation.base_name](state, axes)
# --> 316 matrix = self._asarray(self._get_unitary_matrix(operation), dtype=self.C_DTYPE)
#     318 if operation in diagonal_in_z_basis:
#     319     return self._apply_diagonal_unitary(state, matrix, wires)
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:647, in DefaultQubit._get_unitary_matrix(self, unitary)
#     644 if unitary in diagonal_in_z_basis:
#     645     return unitary.eigvals()
# --> 647 return unitary.matrix()
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/operation.py:745, in Operator.matrix(self, wire_order)
#     725 def matrix(self, wire_order=None):
#     726     r"""Representation of the operator as a matrix in the computational basis.
#     727
#     728     If ``wire_order`` is provided, the numerical representation considers the position of the
#    (...)
#     743         tensor_like: matrix representation
#     744     """
# --> 745     canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#     747     if wire_order is None or self.wires == Wires(wire_order):
#     748         return canonical_matrix
#
# File ~/anaconda3/lib/python3.10/site-packages/pennylane/ops/qubit/parametric_ops_single_qubit.py:205, in RY.compute_matrix(theta)
#     203     s = qml.math.cast_like(s, 1j)
#     204 # The following avoids casting an imaginary quantity to reals when backpropagating
# --> 205 c = (1 + 0j) * c
#     206 s = (1 + 0j) * s
#     207 return qml.math.stack([stack_last([c, -s]), stack_last([s, c])], axis=-2)
#
# File ~/anaconda3/lib/python3.10/site-packages/autograd/numpy/numpy_boxes.py:35, in ArrayBox.__rmul__(self, other)
# ---> 35 def __rmul__(self, other): return anp.multiply(other, self)
#
# KeyboardInterrupt:

# %%
pred_train=np.array([classical_quantum_net(theta,w,t) for t in t])

# %%
plt.figure()
plt.scatter(t,U(t),facecolors='none', edgecolors='b', label='True')
plt.scatter(t,pred_train, color='red',marker="x",s=4,label='Prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
# plt.savefig('1_measurement2_train.png')
plt.show()
