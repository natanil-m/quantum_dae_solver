# %%
#==============================================================================
# Generate data and labels
#==============================================================================
import numpy as np
from math import pi

np.random.seed(0)
m = 100
X = np.linspace(0,0.95,m)
Y = np.sin(np.pi*X)

# %%
# plot data
import matplotlib.pyplot as plt
plt.plot(X,Y,'r-')
plt.show()

# %%
# Encode inputs
#==============================================================================    
import qsimulator as pq
from qsimulator import RX, RY, RZ
n_qubits = 3
def input_prog(sample):
    p = pq.Program(n_qubits)
    for j in range(n_qubits):
        p.inst(RY(np.arcsin(sample[0])), j)
        p.inst(RZ(np.arccos(sample[0]**2)), j)
    return p

# %%
#==============================================================================
# Fully connected transverse Ising model
#==============================================================================   
from qcl import ising_prog_gen 
ising_prog = ising_prog_gen(trotter_steps=1000, T=10, n_qubits=n_qubits)

#==============================================================================
# Output state
#==============================================================================
depth = 3   
def output_prog(theta):
    p = pq.Program(n_qubits)
    theta = theta.reshape(3,n_qubits,depth)
    for i in range(depth):
        p += ising_prog
        for j in range(n_qubits):
            rj = n_qubits-j-1
            p.inst(RX(theta[0,rj,i]), j)
            p.inst(RZ(theta[1,rj,i]), j)
            p.inst(RX(theta[2,rj,i]), j)
    return p

# %%
#==============================================================================
# Gradients
#==============================================================================
def grad_prog(theta, idx, sign):
    theta = theta.reshape(3,n_qubits,depth)
    idx = np.unravel_index(idx, theta.shape)
    p = pq.Program(n_qubits)
    for i in range(depth):
        p += ising_prog
        for j in range(n_qubits):
            rj = n_qubits-j-1
            if idx == (0,rj,i):
                p.inst(RX(sign*np.pi/2.0), j)
            p.inst(RX(theta[0,rj,i]), j)
            if idx == (1,rj,i):
                p.inst(RZ(sign*np.pi/2.0), j)
            p.inst(RZ(theta[1,rj,i]), j)
            if idx == (2,rj,i):
                p.inst(RX(sign*np.pi/2.0), j)
            p.inst(RX(theta[2,rj,i]), j)
    return p

# %%
#==============================================================================
# Quantum Circuit Learning - Regression
#==============================================================================
from qsimulator import Z
from qcl import QCL

state_generators = dict()
state_generators['input'] = input_prog
state_generators['output'] = output_prog
state_generators['grad'] = grad_prog

initial_theta = np.random.uniform(0.0, 2*np.pi, size=3*n_qubits*depth)

operator = pq.Program(n_qubits)
operator.inst(Z, 0)
operator_programs = [operator] 
est = QCL(state_generators, initial_theta, loss="mean_squared_error",  
          operator_programs=operator_programs, epochs=100, batch_size=m,
          verbose=True)

est.fit(X,Y)
results = est.get_results()

X_test = np.linspace(0,1.0,50)
Y_pred = est.predict(X_test)
# Out:
# Epoch: 1/100 ::: Batch: 1/1 ::: Loss: 0.58809
# Epoch: 2/100 ::: Batch: 1/1 ::: Loss: 0.19130
# Epoch: 3/100 ::: Batch: 1/1 ::: Loss: 0.09035
# Epoch: 4/100 ::: Batch: 1/1 ::: Loss: 0.11418
# Epoch: 5/100 ::: Batch: 1/1 ::: Loss: 0.09296
# Epoch: 6/100 ::: Batch: 1/1 ::: Loss: 0.06430
# Epoch: 7/100 ::: Batch: 1/1 ::: Loss: 0.04345
# Epoch: 8/100 ::: Batch: 1/1 ::: Loss: 0.03912
# Epoch: 9/100 ::: Batch: 1/1 ::: Loss: 0.03506
# Epoch: 10/100 ::: Batch: 1/1 ::: Loss: 0.03133
# Epoch: 11/100 ::: Batch: 1/1 ::: Loss: 0.02791
# Epoch: 12/100 ::: Batch: 1/1 ::: Loss: 0.02484
# Epoch: 13/100 ::: Batch: 1/1 ::: Loss: 0.02212
# Epoch: 14/100 ::: Batch: 1/1 ::: Loss: 0.01973
# Epoch: 15/100 ::: Batch: 1/1 ::: Loss: 0.01766
# Epoch: 16/100 ::: Batch: 1/1 ::: Loss: 0.01588
# Epoch: 17/100 ::: Batch: 1/1 ::: Loss: 0.01435
# Epoch: 18/100 ::: Batch: 1/1 ::: Loss: 0.01305
# Epoch: 19/100 ::: Batch: 1/1 ::: Loss: 0.01195
# Epoch: 20/100 ::: Batch: 1/1 ::: Loss: 0.01102
# Epoch: 21/100 ::: Batch: 1/1 ::: Loss: 0.01024
# Epoch: 22/100 ::: Batch: 1/1 ::: Loss: 0.00958
# Epoch: 23/100 ::: Batch: 1/1 ::: Loss: 0.00903
# Epoch: 24/100 ::: Batch: 1/1 ::: Loss: 0.00856
# Epoch: 25/100 ::: Batch: 1/1 ::: Loss: 0.00817
# Epoch: 26/100 ::: Batch: 1/1 ::: Loss: 0.00784
# Epoch: 27/100 ::: Batch: 1/1 ::: Loss: 0.00755
# Epoch: 28/100 ::: Batch: 1/1 ::: Loss: 0.00731
# Epoch: 29/100 ::: Batch: 1/1 ::: Loss: 0.00710
# Epoch: 30/100 ::: Batch: 1/1 ::: Loss: 0.00692
# Epoch: 31/100 ::: Batch: 1/1 ::: Loss: 0.00676
# Epoch: 32/100 ::: Batch: 1/1 ::: Loss: 0.00662
# Epoch: 33/100 ::: Batch: 1/1 ::: Loss: 0.00649
# Epoch: 34/100 ::: Batch: 1/1 ::: Loss: 0.00637
# Epoch: 35/100 ::: Batch: 1/1 ::: Loss: 0.00627
# Epoch: 36/100 ::: Batch: 1/1 ::: Loss: 0.00617
# Epoch: 37/100 ::: Batch: 1/1 ::: Loss: 0.00608
# Epoch: 38/100 ::: Batch: 1/1 ::: Loss: 0.00599
# Epoch: 39/100 ::: Batch: 1/1 ::: Loss: 0.00591
# Epoch: 40/100 ::: Batch: 1/1 ::: Loss: 0.00583
# Epoch: 41/100 ::: Batch: 1/1 ::: Loss: 0.00576
# Epoch: 42/100 ::: Batch: 1/1 ::: Loss: 0.00569
# Epoch: 43/100 ::: Batch: 1/1 ::: Loss: 0.00562
# Epoch: 44/100 ::: Batch: 1/1 ::: Loss: 0.00555
# Epoch: 45/100 ::: Batch: 1/1 ::: Loss: 0.00548
# Epoch: 46/100 ::: Batch: 1/1 ::: Loss: 0.00542
# Epoch: 47/100 ::: Batch: 1/1 ::: Loss: 0.00536
# Epoch: 48/100 ::: Batch: 1/1 ::: Loss: 0.00530
# Epoch: 49/100 ::: Batch: 1/1 ::: Loss: 0.00524
# Epoch: 50/100 ::: Batch: 1/1 ::: Loss: 0.00518
# Epoch: 51/100 ::: Batch: 1/1 ::: Loss: 0.00512
# Epoch: 52/100 ::: Batch: 1/1 ::: Loss: 0.00507
# Epoch: 53/100 ::: Batch: 1/1 ::: Loss: 0.00501
# Epoch: 54/100 ::: Batch: 1/1 ::: Loss: 0.00496
# Epoch: 55/100 ::: Batch: 1/1 ::: Loss: 0.00491
# Epoch: 56/100 ::: Batch: 1/1 ::: Loss: 0.00486
# Epoch: 57/100 ::: Batch: 1/1 ::: Loss: 0.00481
# Epoch: 58/100 ::: Batch: 1/1 ::: Loss: 0.00476
# Epoch: 59/100 ::: Batch: 1/1 ::: Loss: 0.00471
# Epoch: 60/100 ::: Batch: 1/1 ::: Loss: 0.00468
# Epoch: 61/100 ::: Batch: 1/1 ::: Loss: 0.00464
# Epoch: 62/100 ::: Batch: 1/1 ::: Loss: 0.00463
# Epoch: 63/100 ::: Batch: 1/1 ::: Loss: 0.00463
# Epoch: 64/100 ::: Batch: 1/1 ::: Loss: 0.00469
# Epoch: 65/100 ::: Batch: 1/1 ::: Loss: 0.00483
# Epoch: 66/100 ::: Batch: 1/1 ::: Loss: 0.00512
# Epoch: 67/100 ::: Batch: 1/1 ::: Loss: 0.00571
# Epoch: 68/100 ::: Batch: 1/1 ::: Loss: 0.00681
# Epoch: 69/100 ::: Batch: 1/1 ::: Loss: 0.00890
# Epoch: 70/100 ::: Batch: 1/1 ::: Loss: 0.01237
# Epoch: 71/100 ::: Batch: 1/1 ::: Loss: 0.01825
# Epoch: 72/100 ::: Batch: 1/1 ::: Loss: 0.02544
# Epoch: 73/100 ::: Batch: 1/1 ::: Loss: 0.03238
# Epoch: 74/100 ::: Batch: 1/1 ::: Loss: 0.03447
# Epoch: 75/100 ::: Batch: 1/1 ::: Loss: 0.02685
# Epoch: 76/100 ::: Batch: 1/1 ::: Loss: 0.02040
# Epoch: 77/100 ::: Batch: 1/1 ::: Loss: 0.01227
# Epoch: 78/100 ::: Batch: 1/1 ::: Loss: 0.00917
# Epoch: 79/100 ::: Batch: 1/1 ::: Loss: 0.00707
# Epoch: 80/100 ::: Batch: 1/1 ::: Loss: 0.00617
# Epoch: 81/100 ::: Batch: 1/1 ::: Loss: 0.00559
# Epoch: 82/100 ::: Batch: 1/1 ::: Loss: 0.00526
# Epoch: 83/100 ::: Batch: 1/1 ::: Loss: 0.00503
# Epoch: 84/100 ::: Batch: 1/1 ::: Loss: 0.00485
# Epoch: 85/100 ::: Batch: 1/1 ::: Loss: 0.00471
# Epoch: 86/100 ::: Batch: 1/1 ::: Loss: 0.00459
# Epoch: 87/100 ::: Batch: 1/1 ::: Loss: 0.00449
# Epoch: 88/100 ::: Batch: 1/1 ::: Loss: 0.00440
# Epoch: 89/100 ::: Batch: 1/1 ::: Loss: 0.00432
# Epoch: 90/100 ::: Batch: 1/1 ::: Loss: 0.00425
# Epoch: 91/100 ::: Batch: 1/1 ::: Loss: 0.00419
# Epoch: 92/100 ::: Batch: 1/1 ::: Loss: 0.00413
# Epoch: 93/100 ::: Batch: 1/1 ::: Loss: 0.00407
# Epoch: 94/100 ::: Batch: 1/1 ::: Loss: 0.00402
# Epoch: 95/100 ::: Batch: 1/1 ::: Loss: 0.00396
# Epoch: 96/100 ::: Batch: 1/1 ::: Loss: 0.00392
# Epoch: 97/100 ::: Batch: 1/1 ::: Loss: 0.00387
# Epoch: 98/100 ::: Batch: 1/1 ::: Loss: 0.00382
# Epoch: 99/100 ::: Batch: 1/1 ::: Loss: 0.00378
# Epoch: 100/100 ::: Batch: 1/1 ::: Loss: 0.00374

# %%
'''
#==============================================================================
# PLots
#==============================================================================
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X, Y, 'bs', X_test,  Y_pred, 'r-')

# plt.figure()
# plt.plot(np.arange(1,101), results.history_loss, 'bo-')
plt.xticks(np.arange(1,101,4))
plt.xlabel('Epoch')
plt.ylabel('Loss')
'''
# Out:
# "\n#==============================================================================\n# PLots\n#==============================================================================\nimport matplotlib.pyplot as plt\nplt.figure()\nplt.plot(X, Y, 'bs', X_test,  Y_pred, 'r-')\n\n# plt.figure()\n# plt.plot(np.arange(1,101), results.history_loss, 'bo-')\nplt.xticks(np.arange(1,101,4))\nplt.xlabel('Epoch')\nplt.ylabel('Loss')\n"

# %% [markdown]
# ## Performance on training dataset

# %%
pred_train=est.predict(X)

# %%
plt.figure()
plt.scatter(X,Y,facecolors='none', edgecolors='b', label='True')
plt.scatter(X,pred_train, color='red',marker="x",s=4,label='Prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('QCL_sinpix_train.png')
plt.show()

# %% [markdown]
# ## Performance on testing dataset

# %%
X_test=np.linspace(-0.95,0.95,200)
Y_test=np.sin(np.pi*X_test)
test_pred=est.predict(X_test)

# %%
plt.figure()
plt.scatter(X_test,Y_test,facecolors='none', edgecolors='b',label='target')
plt.scatter(X_test,test_pred,color='red',marker="x",s=4,label='prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('QCL_sinpix_test.png')
plt.show()
