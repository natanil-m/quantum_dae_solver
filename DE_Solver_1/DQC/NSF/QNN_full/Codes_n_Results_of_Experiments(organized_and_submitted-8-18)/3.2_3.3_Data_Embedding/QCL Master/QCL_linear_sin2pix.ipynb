# %%
#==============================================================================
# Generate data and labels
#==============================================================================
import numpy as np
from math import pi

np.random.seed(0)
m = 100
X = np.linspace(-0.95,0.95,m)
Y = 0.2*np.sin(2*pi*X)+0.8*np.cos(2*pi*X)**2

# %%
# plot data
import matplotlib.pyplot as plt
plt.plot(X,Y,'r-')
plt.show()

# %%
# Encode inputs
#==============================================================================    
import qsimulator as pq
from qsimulator import RX, RY, RZ
n_qubits = 3
def input_prog(sample):
    p = pq.Program(n_qubits)
    for j in range(n_qubits):
        p.inst(RY(np.arcsin(sample[0])), j)
        p.inst(RZ(np.arccos(sample[0]**2)), j)
    return p

# %%
#==============================================================================
# Fully connected transverse Ising model
#==============================================================================   
from qcl import ising_prog_gen 
ising_prog = ising_prog_gen(trotter_steps=1000, T=10, n_qubits=n_qubits)

#==============================================================================
# Output state
#==============================================================================
depth = 3   
def output_prog(theta):
    p = pq.Program(n_qubits)
    theta = theta.reshape(3,n_qubits,depth)
    for i in range(depth):
        p += ising_prog
        for j in range(n_qubits):
            rj = n_qubits-j-1
            p.inst(RX(theta[0,rj,i]), j)
            p.inst(RZ(theta[1,rj,i]), j)
            p.inst(RX(theta[2,rj,i]), j)
    return p

# %%
#==============================================================================
# Gradients
#==============================================================================
def grad_prog(theta, idx, sign):
    theta = theta.reshape(3,n_qubits,depth)
    idx = np.unravel_index(idx, theta.shape)
    p = pq.Program(n_qubits)
    for i in range(depth):
        p += ising_prog
        for j in range(n_qubits):
            rj = n_qubits-j-1
            if idx == (0,rj,i):
                p.inst(RX(sign*np.pi/2.0), j)
            p.inst(RX(theta[0,rj,i]), j)
            if idx == (1,rj,i):
                p.inst(RZ(sign*np.pi/2.0), j)
            p.inst(RZ(theta[1,rj,i]), j)
            if idx == (2,rj,i):
                p.inst(RX(sign*np.pi/2.0), j)
            p.inst(RX(theta[2,rj,i]), j)
    return p

# %%
#==============================================================================
# Quantum Circuit Learning - Regression
#==============================================================================
from qsimulator import Z
from qcl import QCL

state_generators = dict()
state_generators['input'] = input_prog
state_generators['output'] = output_prog
state_generators['grad'] = grad_prog

initial_theta = np.random.uniform(0.0, 2*np.pi, size=3*n_qubits*depth)

operator = pq.Program(n_qubits)
operator.inst(Z, 0)
operator_programs = [operator] 
est = QCL(state_generators, initial_theta, loss="mean_squared_error",  
          operator_programs=operator_programs, epochs=100, batch_size=m,
          verbose=True)

est.fit(X,Y)
results = est.get_results()

X_test = np.linspace(-1.0,1.0,50)
Y_pred = est.predict(X_test)
# Out:
# Epoch: 1/100 ::: Batch: 1/1 ::: Loss: 0.35131
# Epoch: 2/100 ::: Batch: 1/1 ::: Loss: 0.11170
# Epoch: 3/100 ::: Batch: 1/1 ::: Loss: 0.09950
# Epoch: 4/100 ::: Batch: 1/1 ::: Loss: 0.09708
# Epoch: 5/100 ::: Batch: 1/1 ::: Loss: 0.09576
# Epoch: 6/100 ::: Batch: 1/1 ::: Loss: 0.09469
# Epoch: 7/100 ::: Batch: 1/1 ::: Loss: 0.09375
# Epoch: 8/100 ::: Batch: 1/1 ::: Loss: 0.09293
# Epoch: 9/100 ::: Batch: 1/1 ::: Loss: 0.09221
# Epoch: 10/100 ::: Batch: 1/1 ::: Loss: 0.09158
# Epoch: 11/100 ::: Batch: 1/1 ::: Loss: 0.09102
# Epoch: 12/100 ::: Batch: 1/1 ::: Loss: 0.09053
# Epoch: 13/100 ::: Batch: 1/1 ::: Loss: 0.09010
# Epoch: 14/100 ::: Batch: 1/1 ::: Loss: 0.08972
# Epoch: 15/100 ::: Batch: 1/1 ::: Loss: 0.08939
# Epoch: 16/100 ::: Batch: 1/1 ::: Loss: 0.08909
# Epoch: 17/100 ::: Batch: 1/1 ::: Loss: 0.08883
# Epoch: 18/100 ::: Batch: 1/1 ::: Loss: 0.08859
# Epoch: 19/100 ::: Batch: 1/1 ::: Loss: 0.08838
# Epoch: 20/100 ::: Batch: 1/1 ::: Loss: 0.08819
# Epoch: 21/100 ::: Batch: 1/1 ::: Loss: 0.08802
# Epoch: 22/100 ::: Batch: 1/1 ::: Loss: 0.08786
# Epoch: 23/100 ::: Batch: 1/1 ::: Loss: 0.08772
# Epoch: 24/100 ::: Batch: 1/1 ::: Loss: 0.08758
# Epoch: 25/100 ::: Batch: 1/1 ::: Loss: 0.08745
# Epoch: 26/100 ::: Batch: 1/1 ::: Loss: 0.08733
# Epoch: 27/100 ::: Batch: 1/1 ::: Loss: 0.08722
# Epoch: 28/100 ::: Batch: 1/1 ::: Loss: 0.08711
# Epoch: 29/100 ::: Batch: 1/1 ::: Loss: 0.08700
# Epoch: 30/100 ::: Batch: 1/1 ::: Loss: 0.08690
# Epoch: 31/100 ::: Batch: 1/1 ::: Loss: 0.08680
# Epoch: 32/100 ::: Batch: 1/1 ::: Loss: 0.08670
# Epoch: 33/100 ::: Batch: 1/1 ::: Loss: 0.08660
# Epoch: 34/100 ::: Batch: 1/1 ::: Loss: 0.08650
# Epoch: 35/100 ::: Batch: 1/1 ::: Loss: 0.08641
# Epoch: 36/100 ::: Batch: 1/1 ::: Loss: 0.08631
# Epoch: 37/100 ::: Batch: 1/1 ::: Loss: 0.08622
# Epoch: 38/100 ::: Batch: 1/1 ::: Loss: 0.08612
# Epoch: 39/100 ::: Batch: 1/1 ::: Loss: 0.08603
# Epoch: 40/100 ::: Batch: 1/1 ::: Loss: 0.08593
# Epoch: 41/100 ::: Batch: 1/1 ::: Loss: 0.08584
# Epoch: 42/100 ::: Batch: 1/1 ::: Loss: 0.08574
# Epoch: 43/100 ::: Batch: 1/1 ::: Loss: 0.08565
# Epoch: 44/100 ::: Batch: 1/1 ::: Loss: 0.08555
# Epoch: 45/100 ::: Batch: 1/1 ::: Loss: 0.08545
# Epoch: 46/100 ::: Batch: 1/1 ::: Loss: 0.08535
# Epoch: 47/100 ::: Batch: 1/1 ::: Loss: 0.08526
# Epoch: 48/100 ::: Batch: 1/1 ::: Loss: 0.08516
# Epoch: 49/100 ::: Batch: 1/1 ::: Loss: 0.08506
# Epoch: 50/100 ::: Batch: 1/1 ::: Loss: 0.08495
# Epoch: 51/100 ::: Batch: 1/1 ::: Loss: 0.08485
# Epoch: 52/100 ::: Batch: 1/1 ::: Loss: 0.08475
# Epoch: 53/100 ::: Batch: 1/1 ::: Loss: 0.08465
# Epoch: 54/100 ::: Batch: 1/1 ::: Loss: 0.08454
# Epoch: 55/100 ::: Batch: 1/1 ::: Loss: 0.08444
# Epoch: 56/100 ::: Batch: 1/1 ::: Loss: 0.08433
# Epoch: 57/100 ::: Batch: 1/1 ::: Loss: 0.08423
# Epoch: 58/100 ::: Batch: 1/1 ::: Loss: 0.08412
# Epoch: 59/100 ::: Batch: 1/1 ::: Loss: 0.08401
# Epoch: 60/100 ::: Batch: 1/1 ::: Loss: 0.08390
# Epoch: 61/100 ::: Batch: 1/1 ::: Loss: 0.08379
# Epoch: 62/100 ::: Batch: 1/1 ::: Loss: 0.08368
# Epoch: 63/100 ::: Batch: 1/1 ::: Loss: 0.08357
# Epoch: 64/100 ::: Batch: 1/1 ::: Loss: 0.08346
# Epoch: 65/100 ::: Batch: 1/1 ::: Loss: 0.08335
# Epoch: 66/100 ::: Batch: 1/1 ::: Loss: 0.08324
# Epoch: 67/100 ::: Batch: 1/1 ::: Loss: 0.08312
# Epoch: 68/100 ::: Batch: 1/1 ::: Loss: 0.08301
# Epoch: 69/100 ::: Batch: 1/1 ::: Loss: 0.08289
# Epoch: 70/100 ::: Batch: 1/1 ::: Loss: 0.08278
# Epoch: 71/100 ::: Batch: 1/1 ::: Loss: 0.08266
# Epoch: 72/100 ::: Batch: 1/1 ::: Loss: 0.08254
# Epoch: 73/100 ::: Batch: 1/1 ::: Loss: 0.08243
# Epoch: 74/100 ::: Batch: 1/1 ::: Loss: 0.08231
# Epoch: 75/100 ::: Batch: 1/1 ::: Loss: 0.08219
# Epoch: 76/100 ::: Batch: 1/1 ::: Loss: 0.08207
# Epoch: 77/100 ::: Batch: 1/1 ::: Loss: 0.08195
# Epoch: 78/100 ::: Batch: 1/1 ::: Loss: 0.08183
# Epoch: 79/100 ::: Batch: 1/1 ::: Loss: 0.08171
# Epoch: 80/100 ::: Batch: 1/1 ::: Loss: 0.08158
# Epoch: 81/100 ::: Batch: 1/1 ::: Loss: 0.08146
# Epoch: 82/100 ::: Batch: 1/1 ::: Loss: 0.08134
# Epoch: 83/100 ::: Batch: 1/1 ::: Loss: 0.08121
# Epoch: 84/100 ::: Batch: 1/1 ::: Loss: 0.08109
# Epoch: 85/100 ::: Batch: 1/1 ::: Loss: 0.08096
# Epoch: 86/100 ::: Batch: 1/1 ::: Loss: 0.08084
# Epoch: 87/100 ::: Batch: 1/1 ::: Loss: 0.08071
# Epoch: 88/100 ::: Batch: 1/1 ::: Loss: 0.08059
# Epoch: 89/100 ::: Batch: 1/1 ::: Loss: 0.08046
# Epoch: 90/100 ::: Batch: 1/1 ::: Loss: 0.08033
# Epoch: 91/100 ::: Batch: 1/1 ::: Loss: 0.08021
# Epoch: 92/100 ::: Batch: 1/1 ::: Loss: 0.08008
# Epoch: 93/100 ::: Batch: 1/1 ::: Loss: 0.07995
# Epoch: 94/100 ::: Batch: 1/1 ::: Loss: 0.07982
# Epoch: 95/100 ::: Batch: 1/1 ::: Loss: 0.07969
# Epoch: 96/100 ::: Batch: 1/1 ::: Loss: 0.07956
# Epoch: 97/100 ::: Batch: 1/1 ::: Loss: 0.07943
# Epoch: 98/100 ::: Batch: 1/1 ::: Loss: 0.07930
# Epoch: 99/100 ::: Batch: 1/1 ::: Loss: 0.07917
# Epoch: 100/100 ::: Batch: 1/1 ::: Loss: 0.07904

# %%
'''
#==============================================================================
# PLots
#==============================================================================
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X, Y, 'bs', X_test,  Y_pred, 'r-')

# plt.figure()
# plt.plot(np.arange(1,101), results.history_loss, 'bo-')
plt.xticks(np.arange(1,101,4))
plt.xlabel('Epoch')
plt.ylabel('Loss')
'''
# Out:
# "\n#==============================================================================\n# PLots\n#==============================================================================\nimport matplotlib.pyplot as plt\nplt.figure()\nplt.plot(X, Y, 'bs', X_test,  Y_pred, 'r-')\n\n# plt.figure()\n# plt.plot(np.arange(1,101), results.history_loss, 'bo-')\nplt.xticks(np.arange(1,101,4))\nplt.xlabel('Epoch')\nplt.ylabel('Loss')\n"

# %% [markdown]
# ## Performance on training dataset

# %%
pred_train=est.predict(X)

# %%
plt.figure()
plt.scatter(X,Y,facecolors='none', edgecolors='b', label='True')
plt.scatter(X,pred_train, color='red',marker="x",s=4,label='Prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('QCL_linear_sin2pix_train.png')
plt.show()

# %% [markdown]
# ## Performance on testing dataset

# %%
X_test=np.linspace(-0.95,0.95,200)
Y_test=0.2*np.sin(2*pi*X_test)+0.8*np.cos(2*pi*X_test)**2
test_pred=est.predict(X_test)

# %%
plt.figure()
plt.scatter(X_test,Y_test,facecolors='none', edgecolors='b',label='target')
plt.scatter(X_test,test_pred,color='red',marker="x",s=4,label='prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('QCL_linear_sin2pix_test.png')
plt.show()
