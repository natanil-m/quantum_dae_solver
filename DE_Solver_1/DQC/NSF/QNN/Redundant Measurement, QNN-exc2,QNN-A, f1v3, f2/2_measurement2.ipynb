# %%
from math import pi
import matplotlib.pyplot as plt
from pennylane import numpy as np
import pennylane as qml
from pennylane.optimize import AdamOptimizer
import datetime
now=datetime.datetime.now

# %% [markdown]
# ## Generate data

# %% [markdown]
# $f(x_1,x_2)=0.5\sin(\pi x)\sin(\pi x_2)+0.8\cos^2(\pi x_1)+0.3\sin(\pi x_2)$

# %%
coef=pi
def my_objective(X):
    Y=0.5*np.sin(coef*X[:,0])*np.sin(coef*X[:,1])+0.8*np.cos(coef*X[:,0])**2+0.3*np.sin(coef*X[:,1])
    return Y

# %%
np.random.seed(0)
X=np.random.uniform(-0.95,0.95,size=(100,2),requires_grad=False)

# %%
Y=my_objective(X)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (100, 2)
# (100,)

# %%
# plot data
fig = plt.figure()
ax=plt.axes(projection='3d')
ax.scatter(X[:,0],X[:,1],Y,facecolors='none', edgecolors='b')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(x1,x2)')
plt.title('Training set')
plt.savefig('2_measurement2_target.png')
plt.show()

# %% [markdown]
# ## Set Device

# %%
num_qubits=3
dev=qml.device('default.qubit', wires=num_qubits)

# %% [markdown]
# ## Define embedding layer

# %%
# define my own embedding layer
def myembedding(x,wires):
    qml.RY(coef*x[0], wires=wires[1])
    qml.RY(coef*x[1], wires=wires[2])

# %% [markdown]
# ## Define the Hamiltonian matrix transformation layer

# %%
def Ham():
    obs=[]
    for j in range(num_qubits):
        obs.append(qml.PauliX(j))
        for k in range(j):
            obs.append(qml.PauliZ(j)@qml.PauliZ(k))
    coeffs=np.random.uniform(-1,1,len(obs))*10
    qml.Hamiltonian(coeffs, obs)

# %% [markdown]
# ## Define ansatze

# %%
# define ansastz layer
def layer(theta):
    
    # Apply Hamiltonian matrix
    Ham()
    
    # Apply H gate
    qml.Hadamard(0)
    
    # rotations on qubit 0
    qml.RX(theta[0,0],wires=0)
    qml.RZ(theta[0,1],wires=0)
    qml.RX(theta[0,2],wires=0)
    
    # rotations on qubit 1
    qml.RX(theta[1,0],wires=1)
    qml.RZ(theta[1,1],wires=1)
    qml.RX(theta[1,2],wires=1)
    
    # rotations on qubit 2
    qml.RX(theta[2,0],wires=2)
    qml.RZ(theta[2,1],wires=2)
    qml.RX(theta[2,2],wires=2)
    
    qml.CNOT(wires=[0, 1])
    qml.CNOT(wires=[1, 2])
    qml.CNOT(wires=[0, 2])

# %%
@qml.qnode(dev)
def quantum_net(theta,x):
    
    # encode data
    myembedding(x,wires=range(num_qubits))
    
    # parameterized circuit layers
    for v in theta: # (for lool along with the first dimension)
        # print(v)
        # Ham()
        layer(v)
    
    qml.Hadamard(0)
    
    return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(2))

# %%
num_layers=4
num_rotations=3
theta=np.random.uniform(0,2*pi,size=(num_layers,num_qubits,num_rotations),requires_grad=True)
print(theta.shape)
print(theta)
# Out:
# (4, 3, 3)
# [[[1.9590713  4.37525518 2.37348481]
#   [1.12848319 0.15506102 0.4225419 ]
#   [4.26875069 2.85066135 3.37142662]]
#
#  [[5.63395189 6.22248312 1.36280395]
#   [4.16624322 1.65450329 0.12975406]
#   [4.76503362 2.01072706 2.40937471]]
#
#  [[3.69650544 5.22163144 3.95200948]
#   [5.48302578 1.71871529 5.01427614]
#   [1.16638504 5.98656654 4.31961624]]
#
#  [[1.35407467 5.95250497 4.59210247]
#   [1.5955624  1.34027868 3.25595111]
#   [0.16124361 1.30357293 2.6683775 ]]]

# %%
quantum_net(theta,[0,0])
# Out:
# tensor([-0.0263888 , -0.06231091], requires_grad=True)

# %%
print(qml.draw(quantum_net)(theta,[0,0]))
# Out:
# 0: ──H─────────RX(1.96)──RZ(4.38)──RX(2.37)─╭●────╭●──H─────────RX(5.63)──RZ(6.22)──RX(1.36)─╭●───
# 1: ──RY(0.00)──RX(1.13)──RZ(0.16)──RX(0.42)─╰X─╭●─│───RX(4.17)──RZ(1.65)──RX(0.13)───────────╰X─╭●
# 2: ──RY(0.00)──RX(4.27)──RZ(2.85)──RX(3.37)────╰X─╰X──RX(4.77)──RZ(2.01)──RX(2.41)──────────────╰X
#
# ──╭●──H─────────RX(3.70)──RZ(5.22)──RX(3.95)─╭●────╭●──H─────────RX(1.35)──RZ(5.95)──RX(4.59)─╭●───
# ──│───RX(5.48)──RZ(1.72)──RX(5.01)───────────╰X─╭●─│───RX(1.60)──RZ(1.34)──RX(3.26)───────────╰X─╭●
# ──╰X──RX(1.17)──RZ(5.99)──RX(4.32)──────────────╰X─╰X──RX(0.16)──RZ(1.30)──RX(2.67)──────────────╰X
#
# ──╭●──H─┤  <Z>
# ──│─────┤
# ──╰X────┤  <Z>

# %% [markdown]
# ## Add classical layer

# %%
# add the classical layer
def classical_quantum_net(theta,w,x):
    r1=quantum_net(theta,x)[0]
    r2=quantum_net(theta,x)[1]
    return w[0]+w[1]*r1+w[2]*r1**2+w[3]*r2+w[4]*r2**2

# %%
def square_loss(labels,predictions):
    loss=0
    for l,p in zip(labels,predictions):
        loss=loss+(l-p)**2
    loss=loss/len(labels)
    return loss

# %%
def cost(theta,w,features,labels):
    preds=[classical_quantum_net(theta,w,x) for x in features]
    return square_loss(labels,preds)

# %% [markdown]
# ## Model training
# Using the Adam optimizer, we update the weights for 200 steps (this takes some time). More steps will lead to a better fit.

# %%
w=np.zeros(5,requires_grad=True)
opt = AdamOptimizer(0.05, beta1=0.9, beta2=0.999)

# %%
start=now()
print(start)
# Out:
# 2022-08-06 22:14:27.822743

# %%
epochs=200
for e in range(1,epochs+1):
    
    (theta,w,_,_),_cost=opt.step_and_cost(cost,theta,w,X,Y)

    if e==1 or e%10==0:
        print(f'Epoch: {e} | Cost: {_cost} | w: {w}')
# Out:
# Epoch: 1 | Cost: 0.34125220326158273 | w: [0.04999998 0.0499998  0.04999969 0.04999843 0.04999962]
# Epoch: 10 | Cost: 0.14378135971319558 | w: [0.3263121  0.38666417 0.39285688 0.43534207 0.35276281]
# Epoch: 20 | Cost: 0.07831048161093772 | w: [0.24561268 0.56374066 0.31453662 0.84069195 0.02053835]
# Epoch: 30 | Cost: 0.06532748600438185 | w: [ 0.31603274  0.56165267  0.39627244  0.9860605  -0.20777546]
# Epoch: 40 | Cost: 0.05758613040060296 | w: [ 0.35433765  0.52003343  0.59321805  0.99842551 -0.36460902]
# Epoch: 50 | Cost: 0.04584747553190687 | w: [ 0.35147472  0.50656066  0.89180678  1.03827982 -0.40468771]
# Epoch: 60 | Cost: 0.02626741779243701 | w: [ 0.32971716  0.46138599  1.24438949  1.1504149  -0.31538737]
# Epoch: 70 | Cost: 0.008885582941942265 | w: [ 0.3056333   0.30657305  1.60176043  1.30564659 -0.21041007]
# Epoch: 80 | Cost: 0.0007206524850338284 | w: [ 0.29583183  0.10130841  1.84091521  1.37031743 -0.1328391 ]
# Epoch: 90 | Cost: 0.0007515907766510429 | w: [ 0.28793946  0.07457167  1.91146701  1.39219495 -0.09696338]
# Epoch: 100 | Cost: 0.0006143721248114546 | w: [ 0.28089147  0.10911784  1.91501803  1.38853434 -0.0787687 ]
# Epoch: 110 | Cost: 0.0003052554281673836 | w: [ 0.28089042  0.08439564  1.92779415  1.38573736 -0.06570603]
# Epoch: 120 | Cost: 0.0002187320938259802 | w: [ 0.28204632  0.06172505  1.93651494  1.38146136 -0.05867864]
# Epoch: 130 | Cost: 0.00014956560009775677 | w: [ 0.2818978   0.06403005  1.93229502  1.37219851 -0.05441617]
# Epoch: 140 | Cost: 0.00023077745882562326 | w: [ 0.28134131  0.06271392  1.92783539  1.36385332 -0.0520176 ]
# Epoch: 150 | Cost: 0.00011761056391253628 | w: [ 0.28141465  0.05452321  1.92530301  1.3558796  -0.04906173]
# Epoch: 160 | Cost: 0.00010321774942680539 | w: [ 0.28218073  0.05095826  1.92358549  1.348143   -0.04621252]
# Epoch: 170 | Cost: 6.387966343195773e-05 | w: [ 0.28217401  0.04898152  1.9213781   1.34245289 -0.04413056]
# Epoch: 180 | Cost: 5.0807346385223046e-05 | w: [ 0.28256006  0.04541208  1.92097133  1.33762806 -0.04181141]
# Epoch: 190 | Cost: 0.0006534675221961096 | w: [ 0.28301287  0.04211295  1.92001749  1.33243429 -0.03930503]
# Epoch: 200 | Cost: 0.00016073614351872335 | w: [ 0.28210487  0.03945944  1.9134283   1.32601983 -0.03685554]

# %%
pred_train=np.array([classical_quantum_net(theta,w,x) for x in X])

# %%
fig = plt.figure()
ax=plt.axes(projection='3d')
ax.scatter(X[:,0],X[:,1],Y,facecolors='none', edgecolors='b', label='True')
ax.scatter(X[:,0],X[:,1],pred_train, color='red',marker="x",s=4,label='Prediction')
ax.set_xlabel('x1',fontsize=16)
ax.set_ylabel('x2',fontsize=16)
ax.set_zlabel('f(x1,x2)',fontsize=16)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('2_measurement2_train.png')
plt.show()

# %%
train_diff=np.abs(Y-pred_train)

# %%
np.max(train_diff)
# Out:
# tensor(0.01727844, requires_grad=True)

# %%
np.min(train_diff)
# Out:
# tensor(0.00023086, requires_grad=True)

# %%
np.mean(train_diff)
# Out:
# tensor(0.00605325, requires_grad=True)

# %% [markdown]
# ## Test error

# %%
test1,test2=np.meshgrid(np.linspace(-0.95,0.95,100),np.linspace(-0.95,0.95,100))
test1_flatten=test1.flatten()
test2_flatten=test2.flatten()
X_test=np.concatenate((test1_flatten.reshape(-1,1), test2_flatten.reshape(-1,1)), axis=1)
Y_test=my_objective(X_test)
print(X_test.shape)
print(Y_test.shape)
pred_test=[classical_quantum_net(theta,w,x) for x in zip(test1_flatten,test2_flatten)]
# Out:
# (10000, 2)
# (10000,)

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.scatter(X_test[:,0],X_test[:,1],Y_test,facecolors='none', edgecolors='b',label='target')
ax.scatter(X_test[:,0],X_test[:,1],pred_test,color='red',marker="x",s=4,label='prediction')
ax.set_xlabel('x1',fontsize=16)
ax.set_ylabel('x2',fontsize=16)
ax.set_zlabel('f(x1,x2)',fontsize=16)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('2_measurement2_test.png')
plt.show()

# %%
test_diff=np.abs(Y_test-pred_test)

# %%
np.max(test_diff)
# Out:
# tensor(0.01898132, requires_grad=True)

# %%
np.min(test_diff)
# Out:
# tensor(2.60499774e-06, requires_grad=True)

# %%
np.mean(test_diff)
# Out:
# tensor(0.00639922, requires_grad=True)
