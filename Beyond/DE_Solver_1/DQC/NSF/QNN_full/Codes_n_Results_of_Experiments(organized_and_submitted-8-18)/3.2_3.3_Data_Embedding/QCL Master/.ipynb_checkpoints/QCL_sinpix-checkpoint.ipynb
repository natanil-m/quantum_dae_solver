# %%
#==============================================================================
# Generate data and labels
#==============================================================================
import numpy as np
from math import pi

np.random.seed(0)
m = 100
X = np.linspace(-0.95,0.95,m)
Y = np.sin(np.pi*X)

# %%
# plot data
import matplotlib.pyplot as plt
plt.plot(X,Y,'r-')
plt.show()

# %%
# Encode inputs
#==============================================================================    
import qsimulator as pq
from qsimulator import RX, RY, RZ
n_qubits = 3
def input_prog(sample):
    p = pq.Program(n_qubits)
    for j in range(n_qubits):
        p.inst(RY(np.arcsin(sample[0])), j)
        p.inst(RZ(np.arccos(sample[0]**2)), j)
    return p

# %%
#==============================================================================
# Fully connected transverse Ising model
#==============================================================================   
from qcl import ising_prog_gen 
ising_prog = ising_prog_gen(trotter_steps=1000, T=10, n_qubits=n_qubits)

#==============================================================================
# Output state
#==============================================================================
depth = 3   
def output_prog(theta):
    p = pq.Program(n_qubits)
    theta = theta.reshape(3,n_qubits,depth)
    for i in range(depth):
        p += ising_prog
        for j in range(n_qubits):
            rj = n_qubits-j-1
            p.inst(RX(theta[0,rj,i]), j)
            p.inst(RZ(theta[1,rj,i]), j)
            p.inst(RX(theta[2,rj,i]), j)
    return p

# %%
#==============================================================================
# Gradients
#==============================================================================
def grad_prog(theta, idx, sign):
    theta = theta.reshape(3,n_qubits,depth)
    idx = np.unravel_index(idx, theta.shape)
    p = pq.Program(n_qubits)
    for i in range(depth):
        p += ising_prog
        for j in range(n_qubits):
            rj = n_qubits-j-1
            if idx == (0,rj,i):
                p.inst(RX(sign*np.pi/2.0), j)
            p.inst(RX(theta[0,rj,i]), j)
            if idx == (1,rj,i):
                p.inst(RZ(sign*np.pi/2.0), j)
            p.inst(RZ(theta[1,rj,i]), j)
            if idx == (2,rj,i):
                p.inst(RX(sign*np.pi/2.0), j)
            p.inst(RX(theta[2,rj,i]), j)
    return p

# %%
#==============================================================================
# Quantum Circuit Learning - Regression
#==============================================================================
from qsimulator import Z
from qcl import QCL

state_generators = dict()
state_generators['input'] = input_prog
state_generators['output'] = output_prog
state_generators['grad'] = grad_prog

initial_theta = np.random.uniform(0.0, 2*np.pi, size=3*n_qubits*depth)

operator = pq.Program(n_qubits)
operator.inst(Z, 0)
operator_programs = [operator] 
est = QCL(state_generators, initial_theta, loss="mean_squared_error",  
          operator_programs=operator_programs, epochs=100, batch_size=m,
          verbose=True)

est.fit(X,Y)
results = est.get_results()

X_test = np.linspace(-1.0,1.0,50)
Y_pred = est.predict(X_test)
# Out:
# Epoch: 1/100 ::: Batch: 1/1 ::: Loss: 0.48605
# Epoch: 2/100 ::: Batch: 1/1 ::: Loss: 0.17691
# Epoch: 3/100 ::: Batch: 1/1 ::: Loss: 0.10181
# Epoch: 4/100 ::: Batch: 1/1 ::: Loss: 0.07391
# Epoch: 5/100 ::: Batch: 1/1 ::: Loss: 0.05932
# Epoch: 6/100 ::: Batch: 1/1 ::: Loss: 0.04914
# Epoch: 7/100 ::: Batch: 1/1 ::: Loss: 0.04131
# Epoch: 8/100 ::: Batch: 1/1 ::: Loss: 0.03505
# Epoch: 9/100 ::: Batch: 1/1 ::: Loss: 0.02992
# Epoch: 10/100 ::: Batch: 1/1 ::: Loss: 0.02565
# Epoch: 11/100 ::: Batch: 1/1 ::: Loss: 0.02206
# Epoch: 12/100 ::: Batch: 1/1 ::: Loss: 0.01904
# Epoch: 13/100 ::: Batch: 1/1 ::: Loss: 0.01650
# Epoch: 14/100 ::: Batch: 1/1 ::: Loss: 0.01437
# Epoch: 15/100 ::: Batch: 1/1 ::: Loss: 0.01260
# Epoch: 16/100 ::: Batch: 1/1 ::: Loss: 0.01112
# Epoch: 17/100 ::: Batch: 1/1 ::: Loss: 0.00991
# Epoch: 18/100 ::: Batch: 1/1 ::: Loss: 0.00891
# Epoch: 19/100 ::: Batch: 1/1 ::: Loss: 0.00809
# Epoch: 20/100 ::: Batch: 1/1 ::: Loss: 0.00743
# Epoch: 21/100 ::: Batch: 1/1 ::: Loss: 0.00688
# Epoch: 22/100 ::: Batch: 1/1 ::: Loss: 0.00644
# Epoch: 23/100 ::: Batch: 1/1 ::: Loss: 0.00608
# Epoch: 24/100 ::: Batch: 1/1 ::: Loss: 0.00578
# Epoch: 25/100 ::: Batch: 1/1 ::: Loss: 0.00553
# Epoch: 26/100 ::: Batch: 1/1 ::: Loss: 0.00533
# Epoch: 27/100 ::: Batch: 1/1 ::: Loss: 0.00515
# Epoch: 28/100 ::: Batch: 1/1 ::: Loss: 0.00501
# Epoch: 29/100 ::: Batch: 1/1 ::: Loss: 0.00488
# Epoch: 30/100 ::: Batch: 1/1 ::: Loss: 0.00476
# Epoch: 31/100 ::: Batch: 1/1 ::: Loss: 0.00466
# Epoch: 32/100 ::: Batch: 1/1 ::: Loss: 0.00457
# Epoch: 33/100 ::: Batch: 1/1 ::: Loss: 0.00449
# Epoch: 34/100 ::: Batch: 1/1 ::: Loss: 0.00441
# Epoch: 35/100 ::: Batch: 1/1 ::: Loss: 0.00434
# Epoch: 36/100 ::: Batch: 1/1 ::: Loss: 0.00428
# Epoch: 37/100 ::: Batch: 1/1 ::: Loss: 0.00422
# Epoch: 38/100 ::: Batch: 1/1 ::: Loss: 0.00416
# Epoch: 39/100 ::: Batch: 1/1 ::: Loss: 0.00410
# Epoch: 40/100 ::: Batch: 1/1 ::: Loss: 0.00405
# Epoch: 41/100 ::: Batch: 1/1 ::: Loss: 0.00400
# Epoch: 42/100 ::: Batch: 1/1 ::: Loss: 0.00395
# Epoch: 43/100 ::: Batch: 1/1 ::: Loss: 0.00390
# Epoch: 44/100 ::: Batch: 1/1 ::: Loss: 0.00386
# Epoch: 45/100 ::: Batch: 1/1 ::: Loss: 0.00382
# Epoch: 46/100 ::: Batch: 1/1 ::: Loss: 0.00377
# Epoch: 47/100 ::: Batch: 1/1 ::: Loss: 0.00373
# Epoch: 48/100 ::: Batch: 1/1 ::: Loss: 0.00369
# Epoch: 49/100 ::: Batch: 1/1 ::: Loss: 0.00366
# Epoch: 50/100 ::: Batch: 1/1 ::: Loss: 0.00362
# Epoch: 51/100 ::: Batch: 1/1 ::: Loss: 0.00359
# Epoch: 52/100 ::: Batch: 1/1 ::: Loss: 0.00355
# Epoch: 53/100 ::: Batch: 1/1 ::: Loss: 0.00352
# Epoch: 54/100 ::: Batch: 1/1 ::: Loss: 0.00349
# Epoch: 55/100 ::: Batch: 1/1 ::: Loss: 0.00345
# Epoch: 56/100 ::: Batch: 1/1 ::: Loss: 0.00342
# Epoch: 57/100 ::: Batch: 1/1 ::: Loss: 0.00339
# Epoch: 58/100 ::: Batch: 1/1 ::: Loss: 0.00336
# Epoch: 59/100 ::: Batch: 1/1 ::: Loss: 0.00334
# Epoch: 60/100 ::: Batch: 1/1 ::: Loss: 0.00331
# Epoch: 61/100 ::: Batch: 1/1 ::: Loss: 0.00328
# Epoch: 62/100 ::: Batch: 1/1 ::: Loss: 0.00326
# Epoch: 63/100 ::: Batch: 1/1 ::: Loss: 0.00323
# Epoch: 64/100 ::: Batch: 1/1 ::: Loss: 0.00321
# Epoch: 65/100 ::: Batch: 1/1 ::: Loss: 0.00319
# Epoch: 66/100 ::: Batch: 1/1 ::: Loss: 0.00319
# Epoch: 67/100 ::: Batch: 1/1 ::: Loss: 0.00321
# Epoch: 68/100 ::: Batch: 1/1 ::: Loss: 0.00328
# Epoch: 69/100 ::: Batch: 1/1 ::: Loss: 0.00347
# Epoch: 70/100 ::: Batch: 1/1 ::: Loss: 0.00392
# Epoch: 71/100 ::: Batch: 1/1 ::: Loss: 0.00502
# Epoch: 72/100 ::: Batch: 1/1 ::: Loss: 0.00729
# Epoch: 73/100 ::: Batch: 1/1 ::: Loss: 0.01305
# Epoch: 74/100 ::: Batch: 1/1 ::: Loss: 0.02264
# Epoch: 75/100 ::: Batch: 1/1 ::: Loss: 0.04749
# Epoch: 76/100 ::: Batch: 1/1 ::: Loss: 0.06320
# Epoch: 77/100 ::: Batch: 1/1 ::: Loss: 0.10730
# Epoch: 78/100 ::: Batch: 1/1 ::: Loss: 0.06354
# Epoch: 79/100 ::: Batch: 1/1 ::: Loss: 0.06412
# Epoch: 80/100 ::: Batch: 1/1 ::: Loss: 0.03016
# Epoch: 81/100 ::: Batch: 1/1 ::: Loss: 0.02429
# Epoch: 82/100 ::: Batch: 1/1 ::: Loss: 0.01538
# Epoch: 83/100 ::: Batch: 1/1 ::: Loss: 0.01305
# Epoch: 84/100 ::: Batch: 1/1 ::: Loss: 0.01016
# Epoch: 85/100 ::: Batch: 1/1 ::: Loss: 0.00914
# Epoch: 86/100 ::: Batch: 1/1 ::: Loss: 0.00788
# Epoch: 87/100 ::: Batch: 1/1 ::: Loss: 0.00738
# Epoch: 88/100 ::: Batch: 1/1 ::: Loss: 0.00672
# Epoch: 89/100 ::: Batch: 1/1 ::: Loss: 0.00650
# Epoch: 90/100 ::: Batch: 1/1 ::: Loss: 0.00614
# Epoch: 91/100 ::: Batch: 1/1 ::: Loss: 0.00610
# Epoch: 92/100 ::: Batch: 1/1 ::: Loss: 0.00592
# Epoch: 93/100 ::: Batch: 1/1 ::: Loss: 0.00604
# Epoch: 94/100 ::: Batch: 1/1 ::: Loss: 0.00599
# Epoch: 95/100 ::: Batch: 1/1 ::: Loss: 0.00629
# Epoch: 96/100 ::: Batch: 1/1 ::: Loss: 0.00635
# Epoch: 97/100 ::: Batch: 1/1 ::: Loss: 0.00687
# Epoch: 98/100 ::: Batch: 1/1 ::: Loss: 0.00702
# Epoch: 99/100 ::: Batch: 1/1 ::: Loss: 0.00783
# Epoch: 100/100 ::: Batch: 1/1 ::: Loss: 0.00805

# %%
'''
#==============================================================================
# PLots
#==============================================================================
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X, Y, 'bs', X_test,  Y_pred, 'r-')

# plt.figure()
# plt.plot(np.arange(1,101), results.history_loss, 'bo-')
plt.xticks(np.arange(1,101,4))
plt.xlabel('Epoch')
plt.ylabel('Loss')
'''
# Out:
# "\n#==============================================================================\n# PLots\n#==============================================================================\nimport matplotlib.pyplot as plt\nplt.figure()\nplt.plot(X, Y, 'bs', X_test,  Y_pred, 'r-')\n\n# plt.figure()\n# plt.plot(np.arange(1,101), results.history_loss, 'bo-')\nplt.xticks(np.arange(1,101,4))\nplt.xlabel('Epoch')\nplt.ylabel('Loss')\n"

# %% [markdown]
# ## Performance on training dataset

# %%
pred_train=est.predict(X)

# %%
plt.figure()
plt.scatter(X,Y,facecolors='none', edgecolors='b', label='True')
plt.scatter(X,pred_train, color='red',marker="x",s=4,label='Prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('QCL_sinpix_train.png')
plt.show()

# %% [markdown]
# ## Performance on testing dataset

# %%
X_test=np.linspace(-0.95,0.95,200)
Y_test=np.sin(np.pi*X_test)
test_pred=est.predict(X_test)

# %%
plt.figure()
plt.scatter(X_test,Y_test,facecolors='none', edgecolors='b',label='target')
plt.scatter(X_test,test_pred,color='red',marker="x",s=4,label='prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('QCL_sinpix_test.png')
plt.show()
