# %%
from math import pi
import matplotlib.pyplot as plt
from pennylane import numpy as np
import pennylane as qml
from pennylane.optimize import AdamOptimizer
import datetime
now=datetime.datetime.now

# %% [markdown]
# ## Generate data

# %% [markdown]
# $f(x)=0.2\sin(2\pi x)+0.8\cos^2(2\pi x)$

# %%
coef=2*pi
def my_objective(X):
    Y=0.2*np.sin(coef*X)+0.8*np.cos(coef*X)**2
    return Y

# %%
np.random.seed(2)
X=np.random.uniform(-0.95,0.95,size=100,requires_grad=False)

# %%
Y=my_objective(X)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (100,)
# (100,)

# %%
# plot data
plt.scatter(X,Y,facecolors='none', edgecolors='b')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Training set')
plt.savefig('1_measurement2_target.png')
plt.show()

# %% [markdown]
# ## Set Device

# %%
num_qubits=2
dev=qml.device('default.qubit', wires=num_qubits)

# %% [markdown]
# ## Define embedding layer

# %%
# define my own embedding layer
def myembedding(x,wires):
    qml.RY(coef*x, wires=wires[1])

# %% [markdown]
# ## Define the Hamiltonian matrix transformation layer

# %%
def Ham():
    obs=[]
    for j in range(num_qubits):
        obs.append(qml.PauliX(j))
        for k in range(j):
            obs.append(qml.PauliZ(j)@qml.PauliZ(k))
    coeffs=np.random.uniform(-1,1,len(obs))*10
    qml.Hamiltonian(coeffs, obs)

# %% [markdown]
# ## Define ansatze

# %%
# define ansastz layer
def layer(theta):
    
    # Apply Hamiltonian matrix
    Ham()
    
    # Apply H gate
    qml.Hadamard(0)
    
    # rotations on qubit 1
    qml.RY(theta,wires=1)
    
    # CNOT
    qml.CNOT(wires=[0, 1])

# %%
@qml.qnode(dev)
def quantum_net(theta,x):
    
    # encode data
    myembedding(x,wires=range(num_qubits))
    
    # parameterized circuit layers
    for v in theta: # (for lool along with the first dimension)
        # print(v)
        # Ham()
        layer(v)
    
    qml.Hadamard(0)
    
    return qml.expval(qml.PauliZ(0)),qml.expval(qml.PauliZ(1))

# %%
num_layers=4
theta=np.random.uniform(0,2*pi,size=(num_layers,num_qubits-1),requires_grad=True)
print(theta.shape)
print(theta)
# Out:
# (4, 1)
# [[4.88836944]
#  [0.84165911]
#  [5.45956418]
#  [4.70471016]]

# %%
quantum_net(theta,0)
# Out:
# (tensor([0.98697577], requires_grad=True),
#  tensor([-0.9836307], requires_grad=True))

# %%
print(qml.draw(quantum_net)(theta,0))
# Out:
# 0: ──H────────────────╭●──H──────╭●──H──────╭●──H──────╭●──H─┤  <Z>
# 1: ──RY(0.00)──RY(M0)─╰X──RY(M1)─╰X──RY(M2)─╰X──RY(M3)─╰X────┤  <Z>

# %% [markdown]
# ## Add classical layer

# %%
# add the classical layer
def classical_quantum_net(theta,w,x):
    r1=quantum_net(theta,x)[0]
    r2=quantum_net(theta,x)[1]
    return w[0]+w[1]*r1+w[2]*r1**2+w[3]*r2+w[4]*r2**2

# %%
def square_loss(labels,predictions):
    loss=0
    for l,p in zip(labels,predictions):
        loss=loss+(l-p)**2
    loss=loss/len(labels)
    return loss

# %%
def cost(theta,w,features,labels):
    preds=[classical_quantum_net(theta,w,x) for x in features]
    return square_loss(labels,preds)

# %% [markdown]
# ## Model training
# Using the Adam optimizer, we update the weights for 100 steps (this takes some time). More steps will lead to a better fit.

# %%
w=np.zeros(5,requires_grad=True)
opt = AdamOptimizer(0.05, beta1=0.9, beta2=0.999)

# %%
start=now()
print(start)
# Out:
# 2023-07-25 22:25:06.040479

# %%
epochs=100
for e in range(1,epochs+1):
    
    (theta,w,_,_),_cost=opt.step_and_cost(cost,theta,w,X,Y)

    if e==1 or e%10==0:
        print(f'Epoch: {e} | Cost: {_cost} | w: {w}')
# Out:
# Epoch: 1 | Cost: [0.25207036] | w: [ 0.04999998  0.04999996  0.04999996 -0.04999954  0.04999997]
# Epoch: 10 | Cost: [0.06744372] | w: [0.20225834 0.16029893 0.18995452 0.24125627 0.34328776]
# Epoch: 20 | Cost: [0.02917288] | w: [0.0588001  0.1061885  0.21358133 0.08157728 0.47609431]
# Epoch: 30 | Cost: [0.01850927] | w: [0.0078453  0.09315613 0.31177    0.15544957 0.62494819]
# Epoch: 40 | Cost: [0.00902081] | w: [-0.03997965  0.16379058  0.37293088  0.18855179  0.68598863]
# Epoch: 50 | Cost: [0.00370977] | w: [-0.04814137  0.24993752  0.45641611  0.28894308  0.76825417]
# Epoch: 60 | Cost: [0.00077787] | w: [-0.1212942   0.29163062  0.49597331  0.31534313  0.81831082]
# Epoch: 70 | Cost: [5.77484482e-05] | w: [-0.14466093  0.33078069  0.53127253  0.36052811  0.85404849]
# Epoch: 80 | Cost: [4.56407497e-05] | w: [-0.1617509   0.34115295  0.54077286  0.37257938  0.8678818 ]
# Epoch: 90 | Cost: [3.97008793e-05] | w: [-0.16060527  0.34306788  0.54218476  0.37526341  0.8691423 ]
# Epoch: 100 | Cost: [1.25037665e-05] | w: [-0.15751104  0.33838296  0.53719816  0.36819633  0.86383025]

# %%
pred_train=np.array([classical_quantum_net(theta,w,x) for x in X])

# %%
plt.figure()
plt.scatter(X,Y,facecolors='none', edgecolors='b', label='True')
plt.scatter(X,pred_train, color='red',marker="x",s=4,label='Prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('1_measurement2_train.png')
plt.show()

# %%
train_diff=np.abs(Y-pred_train)

# %%
np.max(train_diff)
# Out:
# tensor(1.01933166, requires_grad=True)

# %%
np.min(train_diff)
# Out:
# tensor(4.17022326e-05, requires_grad=True)

# %%
np.mean(train_diff)
# Out:
# tensor(0.35741151, requires_grad=True)

# %% [markdown]
# ## Test error

# %%
X_test=np.linspace(-0.95,0.95,200)
Y_test=my_objective(X_test)
test_pred=[classical_quantum_net(theta,w,x) for x in X_test]

# %%
plt.figure()
plt.scatter(X_test,Y_test,facecolors='none', edgecolors='b',label='target')
plt.scatter(X_test,test_pred,color='red',marker="x",s=4,label='prediction')
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,1.18),ncol=2,fontsize=16)
plt.savefig('1_measurement2_test.png')
plt.show()

# %%
test_diff=np.abs(Y_test-test_pred)

# %%
np.max(test_diff)
# Out:
# tensor(1.01978893, requires_grad=True)

# %%
np.min(test_diff)
# Out:
# tensor(1.47576612e-05, requires_grad=True)

# %%
np.mean(test_diff)
# Out:
# tensor(0.35863894, requires_grad=True)
