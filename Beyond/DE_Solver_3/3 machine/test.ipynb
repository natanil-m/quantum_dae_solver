# %%
import numpy as np

cos = np.cos

print(cos(np.pi))
print(cos(2*np.pi))
# Out:
# -1.0
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x_values = [0.9020178871027813, 0.8973802997086154, 0.8927939374297158, 0.8882583649363642, 0.8837731450610682, 0.8793378387985601, 0.8749520053057974, 0.8706152019019627, 0.8663269827245573, 0.8620869019990374]
omega3_target_values = [0.9994433541266963, 0.9994494942752077, 0.9994555827438062, 0.9994616193703945, 0.9994676039105025, 0.9994735360372881, 0.9994794153415366, 0.9994852413316613, 0.9994910136243408, 0.9994967326574486]

# Create a higher-resolution x-axis
x_high_res = np.linspace(min(x_values), max(x_values), 1000)

# Interpolate y-values for the higher-resolution x-axis
y_high_res = np.interp(x_high_res, x_values, omega3_target_values)

# Plot the high-resolution data
plt.plot(x_high_res, y_high_res)

# Show the plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('High-Resolution Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

# Your data
x_values = [0.9020178871027813, 0.8973802997086154, 0.8927939374297158, 0.8882583649363642, 0.8837731450610682, 0.8793378387985601, 0.8749520053057974, 0.8706152019019627, 0.8663269827245573, 0.8620869019990374]
omega3_target_values = [0.9994433541266963, 0.9994494942752077, 0.9994555827438062, 0.9994616193703945, 0.9994676039105025, 0.9994735360372881, 0.9994794153415366, 0.9994852413316613, 0.9994910136243408, 0.9994967326574486]



# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data
ax.plot(x_values, omega3_target_values)

# Increase the resolution of the x-axis by setting more ticks
ax.set_xticks(x_values)

# Show the plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Higher-Resolution Plot')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Your data
x_values = [0.9020178871027813, 0.8973802997086154, 0.8927939374297158, 0.8882583649363642, 0.8837731450610682, 0.8793378387985601, 0.8749520053057974, 0.8706152019019627, 0.8663269827245573, 0.8620869019990374]
omega3_target_values = [1.00027538, 1.00027324, 1.00027109, 1.00026894, 1.00026680, 1.00026465, 1.00026251, 1.00026036, 1.00025822, 1.00025607]
fitted_values3 = [0.99993873, 0.99993901, 0.99993929, 0.99993957, 0.99993986, 0.99994014, 0.99994042, 0.9999407, 0.99994098, 0.99994127]

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data
ax.plot(x_values, omega3_target_values, label='Omega3 Target Values')
ax.plot(x_values, fitted_values3, label='Fitted Values3')  # Add this line

# Increase the resolution of the x-axis by setting more ticks
ax.set_xticks(x_values)

# Show the legend
plt.legend()

# Label the axes and add a title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Higher-Resolution Plot')

# Add a grid
plt.grid(True)

# Show the plot
plt.show()
